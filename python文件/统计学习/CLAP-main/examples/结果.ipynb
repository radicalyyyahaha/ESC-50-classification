# %%
# !python zero_shot_classification.py
# Out:
# Loading audio files
# ESC50 Accuracy 0.9385
# 0it [00:00, ?it/s]
# 892it [00:00, 8857.10it/s]
# 1778it [00:00, 8460.73it/s]
# 2000it [00:00, 8377.51it/s]
#
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# model.safetensors:   2%|▏         | 10.5M/548M [00:02<01:52, 4.78MB/s]
# model.safetensors:   4%|▍         | 21.0M/548M [00:02<01:07, 7.85MB/s]
# model.safetensors:   6%|▌         | 31.5M/548M [00:03<00:43, 11.8MB/s]
# model.safetensors:   8%|▊         | 41.9M/548M [00:03<00:35, 14.4MB/s]
# model.safetensors:  10%|▉         | 52.4M/548M [00:04<00:32, 15.1MB/s]
# model.safetensors:  11%|█▏        | 62.9M/548M [00:04<00:29, 16.3MB/s]
# model.safetensors:  13%|█▎        | 73.4M/548M [00:05<00:24, 19.5MB/s]
# model.safetensors:  15%|█▌        | 83.9M/548M [00:06<00:27, 17.0MB/s]
# model.safetensors:  17%|█▋        | 94.4M/548M [00:06<00:20, 22.1MB/s]
# model.safetensors:  19%|█▉        | 105M/548M [00:07<00:27, 16.2MB/s]
# ...

# %%
# !python zero_shot_predictions.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\user\Downloads\CLAP-main\CLAP-main\examples\zero_shot_predictions.py", line 25, in <module>
#     audio_embeddings = clap_model.get_audio_embeddings(audio_files, resample=True)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\ANACONDA\Lib\site-packages\msclap\CLAPWrapper.py", line 282, in get_audio_embeddings
#     preprocessed_audio = self.preprocess_audio(audio_files, resample)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\ANACONDA\Lib\site-packages\msclap\CLAPWrapper.py", line 255, in preprocess_audio
#     audio_tensor = self.load_audio_into_tensor(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\ANACONDA\Lib\site-packages\msclap\CLAPWrapper.py", line 230, in load_audio_into_tensor
#     audio_time_series, sample_rate = self.read_audio(audio_path, resample=resample)
# ...
